# %%
from rdflib import Graph, URIRef, Namespace, Literal, XSD, RDF
from rdflib.plugins.stores.sparqlstore import SPARQLStore
from tqdm.autonotebook import tqdm
import pandas as pd
from copy import deepcopy
import numpy
from sklearn.metrics.pairwise import cosine_similarity
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from collections import defaultdict
from rapidfuzz import process, fuzz, distance
import math

import torch
from transformers import BertTokenizer
from transformers import BertModel
from sklearn.metrics.pairwise import cosine_similarity

# %%
GRAPH_1_INV_FUNC_PATH = ''
GRAPH_1 = ""
GRAPH_2_INV_FUNC_PATH = ''
GRAPH_2 = ""
#GRAPH_2 = "http://localhost:9999/bigdata/sparql"
SUBJECT = 'subject'
PREDICATE = 'predicate'
INVERSE_FUNCTIONALITY = 'inverse_functionality'

# %%
graph_1_inv_func_df = pd.read_csv(GRAPH_1_INV_FUNC_PATH)

threshold_graph_1_inv_func_df = graph_1_inv_func_df[graph_1_inv_func_df[INVERSE_FUNCTIONALITY] > 0.5]

#graph_1_predicate_list = threshold_graph_1_inv_func_df[PREDICATE].tolist()

graph_1 = Graph()
graph_1.parse(GRAPH_1)
# Out:
# <Graph identifier=N3ee65592845f4ef787f6711e12c397d8 (<class 'rdflib.graph.Graph'>)>

# %%
graph_2_inv_func_df = pd.read_csv(GRAPH_2_INV_FUNC_PATH)

threshold_graph_2_inv_func_df = graph_2_inv_func_df[graph_2_inv_func_df[INVERSE_FUNCTIONALITY] > 0.5]

#graph_2_predicate_list = threshold_graph_2_inv_func_df[PREDICATE].tolist()

graph_2 = Graph()
graph_2.parse(GRAPH_2)
#graph_2 = Graph("SPARQLStore")
#graph_2.open(GRAPH_2)
# Out:
# <Graph identifier=Na9220770da9e419bb02fb239d042e083 (<class 'rdflib.graph.Graph'>)>

# %%
def get_label_graph(graph, predicate_df):
    predicate_label_list = list()
    LABEL = "http://www.w3.org/2000/01/rdf-schema#label"
    label_predicate = URIRef(LABEL)
    for index, row in tqdm(predicate_df.iterrows(), total=len(predicate_df)):
        search_uriref = URIRef(row['predicate'])
        label = str(next(graph.objects(search_uriref, label_predicate), ""))
        predicate_label_list.append(label)
    return predicate_label_list

predicate_1_list = get_label_graph(graph_1, graph_1_inv_func_df) 
graph_1_inv_func_df['labels'] = predicate_1_list

predicate_2_list = get_label_graph(graph_2, graph_2_inv_func_df) 
graph_2_inv_func_df['labels'] = predicate_2_list

graph_1_predicate_set = set(graph_1_inv_func_df['predicate'])
graph_2_predicate_set = set(graph_2_inv_func_df['predicate'])

predicate_prob_dict = dict()

for predicate_uri in graph_1_predicate_set:
    if predicate_uri in graph_2_predicate_set:
        predicate_prob_dict.setdefault(predicate_uri, {})
        predicate_prob_dict[predicate_uri][predicate_uri] = 1.0
# Out:
#   0%|          | 0/342 [00:00<?, ?it/s]
#   0%|          | 0/218 [00:00<?, ?it/s]

# %%
def match_predicate_labels(predicate_prob_dict, graph_1_inv_func_df, graph_2_inv_func_df, label_column, max_score):
    graph_2_predicate_labels_dict = {label: list(graph_2_inv_func_df.loc[graph_2_inv_func_df[label_column] == label, 'predicate'])
           for label in graph_2_inv_func_df[label_column].unique()}
    
    del graph_2_predicate_labels_dict['']
    
    for _, row in graph_1_inv_func_df.iterrows():
        label = row[label_column]
        predicate_1 = row['predicate']
        if label in graph_2_predicate_labels_dict:
            for predicate_2 in graph_2_predicate_labels_dict[label]:
                if predicate_1 in predicate_prob_dict.keys() and predicate_2 in predicate_prob_dict[predicate_1].keys():
                    continue
                predicate_prob_dict.setdefault(predicate_1, {})[predicate_2] = max_score

# %%
match_predicate_labels(predicate_prob_dict, graph_1_inv_func_df, graph_2_inv_func_df, 'labels', 0.9)

# %%
def normalize_string(s):
    # remove punctuation
    s = s.translate(str.maketrans('', '', string.punctuation))
    # split the string at uppercase letters and digits and join with spaces
    s = re.sub(r'([a-z])([A-Z])', r'\1 \2', s)
    s = re.sub(r'([A-Z])([A-Z][a-z])', r'\1 \2', s)
    s = re.sub(r'([a-zA-Z])(\d)', r'\1 \2', s)
    s = re.sub(r'(\d)([a-zA-Z])', r'\1 \2', s)
    # replace underscores with spaces
    s = s.replace('_', ' ')
    # remove multiple consecutive spaces and leading/trailing spaces
    s = ' '.join(s.split()).strip()
    # convert to lowercase and return
    return s.lower()

# %%
graph_1_inv_func_df['normalized label'] = graph_1_inv_func_df['labels'].apply(normalize_string)
graph_2_inv_func_df['normalized label'] = graph_2_inv_func_df['labels'].apply(normalize_string)

match_predicate_labels(predicate_prob_dict, graph_1_inv_func_df, graph_2_inv_func_df, 'normalized label', 0.8)

# %%
nltk.download('stopwords') # download stop words list

stop_words = set(stopwords.words('english')) # set of English stop words

def remove_stopwords(s):
    words = s.split() # split text into individual words

    filtered_words = [word for word in words if not word.lower() in stop_words] # remove stop words

    filtered_text = ' '.join(filtered_words)
    return filtered_text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yamamotobikutorueiichi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
LABEL = 'stopword label'

graph_1_inv_func_df[LABEL] = graph_1_inv_func_df['normalized label'].apply(remove_stopwords)
graph_2_inv_func_df[LABEL] = graph_2_inv_func_df['normalized label'].apply(remove_stopwords)

match_predicate_labels(predicate_prob_dict, graph_1_inv_func_df, graph_2_inv_func_df, LABEL, 0.7)

# %%
def remove_corpus_specific_stopword(graph_df):
    doc_freq = defaultdict(int)

    for _, row in graph_df.iterrows():
        doc = row['stopword label']
        words = set(word_tokenize(doc))
        for word in words:
            doc_freq[word] += 1
            
    total_docs = len(graph_df)
    corpus_stopwords = set()
    for word, freq in doc_freq.items():
        if freq / total_docs > 0.2: # word appears in more than 20% of documents
            corpus_stopwords.add(word)    
    label_list = list()
    for _, row in graph_df.iterrows():
        words = word_tokenize(row['stopword label'])
        filtered_words = [word for word in words if not word.lower() in corpus_stopwords]
        filtered_text = ' '.join(filtered_words)
        label_list.append(filtered_text)
    
    graph_df['corpus stopword label'] = label_list

# %%
remove_corpus_specific_stopword(graph_1_inv_func_df)
remove_corpus_specific_stopword(graph_2_inv_func_df)

LABEL = 'corpus stopword label'

for _, row in graph_1_inv_func_df.iterrows():
    label_1 = row[LABEL]
    predicate_1 = row['predicate']
    if not label_1:
        continue
    
    for _, row_2 in graph_2_inv_func_df.iterrows():
        label_2 = row_2[LABEL]
        predicate_2 = row_2['predicate']
        if not label_2:
            continue
        if not predicate_1 in predicate_prob_dict.keys() or not predicate_2 in predicate_prob_dict[predicate_1]:
            sim = fuzz.WRatio(label_1, label_2) / 100
            prob = 0.6 * sim
            predicate_prob_dict.setdefault(predicate_1, {})[predicate_2] = prob

# %%
nltk_tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained("bert-base-uncased")
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def embed_long_sentence(long_sentence):
    sentences = nltk_tokenizer.tokenize(long_sentence)
    
    tokens = {'input_ids': [], 'attention_mask': []}

    max_token = 140
    for sentence in sentences:
        new_tokens = tokenizer.encode_plus(sentence, return_tensors="pt", max_length=max_token, padding='max_length')
        tokens['input_ids'].append(new_tokens['input_ids'][0][:max_token])
        tokens['attention_mask'].append(new_tokens['attention_mask'][0][:max_token])

    tokens['input_ids'] = torch.stack(tokens['input_ids'])
    tokens['attention_mask'] = torch.stack(tokens['attention_mask'])
    
    outputs = model(**tokens)
    
    embeddings = outputs.last_hidden_state
    
    attention_mask = tokens['attention_mask']
    
    mask = attention_mask.unsqueeze(-1).expand(embeddings.size()).float()

    masked_embeddings = embeddings * mask
    
    summed = torch.sum(masked_embeddings, 1)

    summed_mask = torch.clamp(mask.sum(1), min=1e-9)

    mean_pooled = summed / summed_mask
    
    return mean_pooled.detach().numpy()

# %%
def get_label_vec_dict(df):
    LABEL = 'corpus stopword label'

    df_label_set = set(df[LABEL])
    df_label_vec_dict = dict()

    for label in tqdm(df_label_set):
        if not label:
            continue

        df_label_vec_dict[label] = embed_long_sentence(label)
    return df_label_vec_dict

# %%
graph_2_label_vec_dict = get_label_vec_dict(graph_2_inv_func_df)
# Out:
#   0%|          | 0/194 [00:00<?, ?it/s]

# %%
LABEL = 'corpus stopword label'

for _, row in tqdm(graph_1_inv_func_df.iterrows(), total=len(graph_1_inv_func_df)):
    label_1 = row[LABEL]
    predicate_1 = row['predicate']
    if not label_1:
        continue
    vec_1 = embed_long_sentence(label_1)
    
    for _, row_2 in graph_2_inv_func_df.iterrows():
        predicate_2 = row_2['predicate']
        label_2 = row_2[LABEL]
        
        if not label_2:
            continue
        
        if predicate_prob_dict[predicate_1][predicate_2] > 0.5:
            continue
        
        vec_2 = graph_2_label_vec_dict[row_2[LABEL]]
        
        similarities = cosine_similarity(vec_1, vec_2)
        max_similarity = max(map(max, similarities))
        prob = 0.5 * max_similarity
        
        if prob > predicate_prob_dict[predicate_1][predicate_2]:
            predicate_prob_dict[predicate_1][predicate_2] = prob
# Out:
#   0%|          | 0/342 [00:00<?, ?it/s]

# %%
literal_y1_dict = dict()
used_p1_dict = dict()
graph_1_predicate_list = list()

for index, row in tqdm(threshold_graph_1_inv_func_df.iterrows(), total=len(threshold_graph_1_inv_func_df)):
    predicate = row[PREDICATE]
    predicate_uri = URIRef(predicate)
    
    if sum(1 for _ in graph_1.subject_objects(predicate_uri)) < 5:
        continue
    
    graph_1_predicate_list.append(predicate)
    
    for s, p, o in graph_1.triples((None, predicate_uri, None)):

        if type(o) != Literal or not isinstance(o, Literal) or not (o.datatype is None or o.datatype == XSD.string or o.datatype == RDF.langString):
            continue
        
        o_value = str(o)
        if o_value not in literal_y1_dict.keys():
            literal_y1_dict[o_value] = list()
        y1_value_list = literal_y1_dict[o_value]
        y1_value_list.append({
            SUBJECT: s,
            PREDICATE: predicate_uri
        })
# Out:
#   0%|          | 0/205 [00:00<?, ?it/s]

# %%
y2_matches = dict()
graph_2_predicate_list = list()

for index, row in tqdm(threshold_graph_2_inv_func_df.iterrows(), total=len(threshold_graph_2_inv_func_df)):
    predicate = row[PREDICATE]
    predicate_uri = URIRef(predicate)
    
    if sum(1 for _ in graph_2.subject_objects(predicate_uri)) < 5:
        continue
        
    graph_2_predicate_list.append(predicate)
    
    for s, o in graph_2.subject_objects(predicate_uri):
        if type(o) != Literal or not isinstance(o, Literal) or not (o.datatype is None or o.datatype == XSD.string or o.datatype == RDF.langString):
            continue
        
        # Check if exist match
        o_value = str(o)
        if o_value not in literal_y1_dict.keys():
            continue
            
        if o_value not in y2_matches.keys():
            y2_matches[o_value] = list()
        y2_match_list = y2_matches[o_value]
        y2_match_list.append({
            SUBJECT: s,
            PREDICATE: predicate_uri
        })
# Out:
#   0%|          | 0/151 [00:00<?, ?it/s]

# %%
def get_predicate_prob(predicate_pair_dict, p1, p2):
    if p1 not in predicate_pair_dict.keys():
        predicate_pair_dict[p1] = dict()
    if p2 not in predicate_pair_dict[p1].keys():
        predicate_pair_dict[p1][p2] = 0.1

    return predicate_pair_dict[p1][p2]

# %%
inv_func_1_dict = dict()

for index, row in tqdm(threshold_graph_1_inv_func_df.iterrows(), total=len(threshold_graph_1_inv_func_df)):
    inv_func_1_dict[row['predicate']] = row['inverse_functionality']
# Out:
#   0%|          | 0/205 [00:00<?, ?it/s]

# %%
inv_func_2_dict = dict()

for index, row in tqdm(threshold_graph_2_inv_func_df.iterrows(), total=len(threshold_graph_2_inv_func_df)):
    inv_func_2_dict[row['predicate']] = row['inverse_functionality']
# Out:
#   0%|          | 0/151 [00:00<?, ?it/s]

# %%
def save_predicate_pair(predicate_pair_counter, x1, p1, y1, x2, p2, y2):
    predicate_pair_counter.append({
        'x1': x1,
        'p1': p1,
        'y1': y1,
        'x2': x2,
        'p2': p2,
        'y2': y2,
    })

# %%
def update_prob_entities(entity_pair_match_dict, x1, x2, p1, p2, prob_y):
    if x1 not in entity_pair_match_dict.keys():
        entity_pair_match_dict[x1] = dict()
    if x2 not in entity_pair_match_dict[x1].keys():
        entity_pair_match_dict[x1][x2] = 1
    #if x1 == 'http://dbkwik.webdatacommons.org/finalfantasy./resource/Toad_(Final_Fantasy_V_enemy)':
    #    print(len(entity_pair_match_dict[x1]))
    
    y1_pred = str(p1)
    y2_pred = str(p2)
    pred_prob_1_2 = get_predicate_prob(predicate_pair_dict_1, y1_pred, y2_pred)
    pred_prob_2_1 = get_predicate_prob(predicate_pair_dict_2, y2_pred, y1_pred)

    new_factor = (1-pred_prob_1_2*inv_func_1_dict[y1_pred] * prob_y) * (1-pred_prob_2_1*inv_func_2_dict[y2_pred] * prob_y)

    entity_pair_match_dict[x1][x2] *= new_factor

    return 1 - entity_pair_match_dict[x1][x2]

# %%
def calculate_entity_prob_using_attribute(new_entity_pair_match_dict):
    for o_value, y2_match_list in tqdm(y2_matches.items(), desc='Attribute loop', leave=False):
        y1_match_list = literal_y1_dict[o_value]

        for y1_match in y1_match_list:
            y1_subject = y1_match['subject']

            for y2_match in y2_match_list:
                y2_subject = y2_match['subject']


                y1_pred = str(y1_match['predicate'])
                y2_pred = str(y2_match['predicate'])
                sim = update_prob_entities(new_entity_pair_match_dict, str(y1_subject), str(y2_subject),
                                     y1_pred, y2_pred, 1)

                if sim > 0.1:
                    save_predicate_pair(predicate_pair_counter, str(y1_subject), y1_pred, o_value, str(y2_subject),
                                        y2_pred, o_value)

# %%
def get_inbound_neighbors(graph, predicate_list, y, loaded_neighbors_dict):
    if not y:
        return []
    
    if y in loaded_neighbors_dict.keys():
        return loaded_neighbors_dict[y]
    
    y_url = y
    if type(y_url) != URIRef:
        y_url = URIRef(y)
    
    attempts = 0
    while attempts < 10:
        try:
            neighbor_list = list()
            for s, p in graph.subject_predicates(y_url):
                if str(p) in predicate_list:
                    neighbor_list.append({
                        'p': p,
                        's': s
                    })
            return neighbor_list
        except Exception as e:
            print(e)
            attempts += 1
    loaded_neighbors_dict[y] = neighbor_list
    return neighbor_list

# %%
def update_prob_entity_neighbors(entity_pair_dict, y1_neighbors,
                                 y2_neighbors, y_sim, y1, y2):
    for x1 in y1_neighbors:
        for x2 in y2_neighbors:
            x1_str = str(x1['s'])
            x2_str = str(x2['s'])
            p1_str = str(x1['p'])
            p2_str = str(x2['p'])
            sim = update_prob_entities(entity_pair_dict, x1_str, x2_str, p1_str, str(x2['p']),
                                 y_sim)
            if sim > 0.1:
                save_predicate_pair(predicate_pair_counter, x1_str, p1_str, str(y1), x2_str, p2_str, str(y2))

# %%
def calculate_entity_prob_using_neighbors(new_entity_pair_dict, old_entity_pair_dict, loaded_neighbors_dict):
    y1_keys = list(old_entity_pair_dict.keys())
    for y1 in tqdm(y1_keys, desc='neighbor loop', leave=False):
        y1_neighbors = get_inbound_neighbors(graph_1, graph_1_predicate_list, y1, loaded_neighbors_dict)
        y2_keys = list(old_entity_pair_dict[y1].keys())
        for y2 in y2_keys:
            y_sim = 1
            if y1 in new_entity_pair_dict.keys() and y2 in new_entity_pair_dict[y1].keys():
                y_sim -= new_entity_pair_dict[y1][y2]
            else:
                y_sim -= old_entity_pair_dict[y1][y2]
            if y_sim < 0.2:
                continue
            
            y2_neighbors = get_inbound_neighbors(graph_2, graph_2_predicate_list, y2, loaded_neighbors_dict)
            update_prob_entity_neighbors(new_entity_pair_dict, y1_neighbors, y2_neighbors, y_sim, y1, y2)

# %%
def get_prob_entity_pair(entity_pair_match_dict, s1, s2):
    if s1 in entity_pair_match_dict.keys() and s2 in entity_pair_match_dict[s1].keys():
        return 1 - entity_pair_match_dict[s1][s2]
    return 0

# %%
def get_set_of_triples_by_predicate(predicate_pair_counter_df, reversed_bool):
    if reversed_bool:
        return predicate_pair_counter_df[['x2', 'p2', 'y2']].drop_duplicates()
    else:
        return predicate_pair_counter_df[['x1', 'p1', 'y1']].drop_duplicates()

# %%
def get_columns(reversed_bool):
    if reversed_bool:
        return {
            'x1': 'x2',
            'p1': 'p2',
            'y1': 'y2',
            'x2': 'x1',
            'p2': 'p1',
            'y2': 'y1'
        }
    else:
        return {
            'x1': 'x1',
            'p1': 'p1',
            'y1': 'y1',
            'x2': 'x2',
            'p2': 'p2',
            'y2': 'y2'
        }

# %%
def calculate_product(matched_row, entity_pair_match_dict):
    x_sim = 1 - entity_pair_match_dict[matched_row['x1']][matched_row['x2']]
    if matched_row['y1'] == matched_row['y2']:
        y_sim = 1
    else:
        y_sim = entity_pair_match_dict[matched_row['y1']][matched_row['y2']]
    return 1 - x_sim * y_sim

# %%
def calculate_sum_by_triple(indexed_df, triple_row):
    matched_triples = indexed_df.join(triple_row)
    return 1.0 - numpy.product(matched_triples['product_element'])

# %%
def calculate_upper_sum(entity_pair_match_dict, predicate_pair_counter_df, unique_triples, p1, p2, reversed_bool):
    columns = get_columns(reversed_bool)
    
    filtered_by_ps_df = predicate_pair_counter_df[predicate_pair_counter_df[columns['p2']].isin([p2])]
    
    grouped_df = filtered_by_ps_df.groupby([columns['x1'], columns['y1']])
    product = grouped_df['product_element'].prod()
    return (1 - product).sum()

# %%
def calculate_lower_sum(entity_pair_match_dict, predicate_pair_counter_df, unique_triples, p1, reversed_bool):
    columns = get_columns(reversed_bool)
    
    grouped_df = predicate_pair_counter_df.groupby([columns['x1'], columns['y1']])
    product = grouped_df['product_element'].prod()
    
    return (1 - product).sum()

# %%
def calculate_x_sim(x1, x2, entity_pair_match_dict, reversed_bool):
    if reversed_bool:
        return 1 - entity_pair_match_dict[x2][x1]
    return 1 - entity_pair_match_dict[x1][x2]

# %%
def calculate_y_sim(y1, y2, entity_pair_match_dict, reversed_bool):
    if y1 == y2:
        return 1
    else:
        if reversed_bool:
            if y2 in entity_pair_match_dict.keys() and y1 in entity_pair_match_dict[y2].keys():
                return 1 - entity_pair_match_dict[y2][y1]
        if y1 in entity_pair_match_dict.keys() and y2 in entity_pair_match_dict[y1].keys():
            return 1 - entity_pair_match_dict[y1][y2]
    return 0

# %%
def calculate_sub_predicates(predicate_sub_relation, predicate_pair_dict, predicate_pair_counter, entity_pair_match_dict, reversed_bool):
    columns = get_columns(reversed_bool)
    predicate_pair_counter_df = pd.DataFrame(predicate_pair_counter)
    
    predicate_pair_counter_df['x_sim'] = predicate_pair_counter_df.apply(lambda x: calculate_x_sim(x[columns["x1"]], x[columns["x2"]], entity_pair_match_dict, reversed_bool), axis=1)
    predicate_pair_counter_df['y_sim'] = predicate_pair_counter_df.apply(lambda x: calculate_y_sim(x[columns["y1"]], x[columns["y2"]], entity_pair_match_dict, reversed_bool), axis=1)

    predicate_pair_counter_df['product_element'] = predicate_pair_counter_df.apply(lambda x: 1.0 - x['x_sim'] * x['y_sim'], axis=1)

    for p1 in tqdm(predicate_pair_dict.keys(), desc='Predicate loop', leave=False):
        filtered_counter = predicate_pair_counter_df[predicate_pair_counter_df[columns['p1']].isin([p1])]
        if len(filtered_counter) < 10:
            for p2 in predicate_pair_dict[p1].keys():
                predicate_sub_relation.setdefault(p1, {})[p2] = 0.0
        unique_triples = get_set_of_triples_by_predicate(filtered_counter, reversed_bool)
        for p2 in predicate_pair_dict[p1].keys():
            predicate_sub_relation.setdefault(p1, {})[p2] = calculate_upper_sum(entity_pair_match_dict, filtered_counter, unique_triples, p1,
                                                              p2, reversed_bool)
        
        lower_sum = calculate_lower_sum(entity_pair_match_dict, filtered_counter, unique_triples, p1, reversed_bool)
        if lower_sum == 0.0:
            continue
        for p2 in predicate_sub_relation[p1].keys():
            predicate_sub_relation[p1][p2] /= lower_sum

# %%
def get_subject_object(graph, predicate):
    attempts = 0
    while attempts < 10:
        try:
            s_o_list = list()
            for s, o in graph.subject_objects(URIRef(predicate)):
                s_o_list.append({
                        'subject': s,
                        'object': o
                    })
            return s_o_list
        except Exception as e:
            print(e)
            attempts += 1
    
    return s_o_list

# %%
def check_if_string(y):
    return type(y) == Literal and y.value and type(y.value) == str

# %%
def calculate_sub_pred_product(entity_pair_match_dict, x1, x2, y1, y2):
    if check_if_string(y1) and check_if_string(y2):
        if y1.value != y2.value:
            return 0.0
        y_value = y1.value
        if y_value not in literal_y1_dict.keys() or y_value not in y2_matches.keys():
            return 0.0
        return entity_pair_match_dict[str(x1)][str(x2)]
    return 0.0

# %%
def save_entity_pairs(i, entity_pair_match_dict):
    entity_pair_sim_list = list()
    for y1 in entity_pair_match_dict.keys():
        for y2 in entity_pair_match_dict[y1].keys():
            similarity = 1 - entity_pair_match_dict[y1][y2]
            entity_pair_sim_list.append({
                "e1": y1,
                "e2": y2,
                "sim": similarity
            })
    entity_sim_df = pd.DataFrame(entity_pair_sim_list)
    entity_sim_df.to_csv("ma-se-pre-calc-pred/entity_sim_" + str(i) + ".csv")

# %%
def save_predicate_pairs_into_df(i, predicate_pair_dict, name):
    predicate_pair_list = list()
    for p1 in predicate_pair_dict.keys():
        for p2 in predicate_pair_dict[p1].keys():
            predicate_pair_list.append({
                "p1": p1,
                "p2": p2,
                "sim": predicate_pair_dict[p1][p2]
            })
    predicate_pair_df = pd.DataFrame(predicate_pair_list)
    predicate_pair_df.to_csv(name + str(i) + ".csv")

# %%
def pre_calc_pred_pair_dict(predicate_prob_dict, pred_sub_relation, reversed_bool):
    new_predicate_pair_dict = dict()
    
    for pred_1, pred_2_dict in pred_sub_relation.items():
        for pred_2 in pred_2_dict:
            if reversed_bool:
                if pred_1 not in new_predicate_pair_dict.get(pred_2, {}):
                    new_predicate_pair_dict.setdefault(pred_2, {})[pred_1] = 0
                new_predicate_pair_dict[pred_2][pred_1] += 0.5 * pred_sub_relation[pred_1][pred_2]
            else:
                if pred_2 not in new_predicate_pair_dict.get(pred_1, {}):
                    new_predicate_pair_dict.setdefault(pred_1, {})[pred_2] = 0
                new_predicate_pair_dict[pred_1][pred_2] += 0.5 * pred_sub_relation[pred_1][pred_2]

    for pred_1 in predicate_prob_dict:
        for pred_2 in predicate_prob_dict[pred_1]:
            if reversed_bool:
                if pred_1 not in new_predicate_pair_dict.get(pred_2, {}):
                    new_predicate_pair_dict.setdefault(pred_2, {})[pred_1] = 0
                new_predicate_pair_dict[pred_2][pred_1] += 0.5 * predicate_prob_dict[pred_1][pred_2]
            else:
                if pred_2 not in new_predicate_pair_dict.get(pred_1, {}):
                    new_predicate_pair_dict.setdefault(pred_1, {})[pred_2] = 0
                new_predicate_pair_dict[pred_1][pred_2] += 0.5 * predicate_prob_dict[pred_1][pred_2]

    return new_predicate_pair_dict

# %%
old_entity_pair_match_dict = dict()
loaded_neighbors_dict = dict()
pred_sub_relation_1 = dict()
pred_sub_relation_2 = dict()

for i in tqdm(range(10), desc='Main loop'):
    predicate_pair_dict_1 = pre_calc_pred_pair_dict(predicate_prob_dict, pred_sub_relation_1, False)
    predicate_pair_dict_2 = pre_calc_pred_pair_dict(predicate_prob_dict, pred_sub_relation_2, True)
    predicate_pair_counter = list()
    
    save_predicate_pairs_into_df(i, predicate_pair_dict_1, "ma-se-pre-calc-pred/predicate_pair_1_")
    save_predicate_pairs_into_df(i, predicate_pair_dict_2, "ma-se-pre-calc-pred/predicate_pair_2_")

    new_entity_pair_match_dict = dict()
    
    calculate_entity_prob_using_attribute(new_entity_pair_match_dict)     
    
    calculate_entity_prob_using_neighbors(new_entity_pair_match_dict, old_entity_pair_match_dict, loaded_neighbors_dict)

    #calculate_prob_predicates(predicate_pair_dict, new_entity_pair_match_dict)
    calculate_sub_predicates(pred_sub_relation_1, predicate_pair_dict_1, predicate_pair_counter, new_entity_pair_match_dict, False)
    calculate_sub_predicates(pred_sub_relation_2, predicate_pair_dict_2, predicate_pair_counter, new_entity_pair_match_dict, True)
    
    save_entity_pairs(i, new_entity_pair_match_dict)
    old_entity_pair_match_dict = new_entity_pair_match_dict
# Out:
# Main loop:   0%|          | 0/10 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11007 [00:00<?, ?it/s]
# neighbor loop: 0it [00:00, ?it/s]
# Predicate loop:   0%|          | 0/337 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/213 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11007 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/11621 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/337 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/534 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11007 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/14209 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/337 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/534 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11007 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/14862 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/337 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/534 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11007 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/15057 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/337 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/534 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11007 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/15133 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/337 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/534 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11007 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/15184 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/337 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/534 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11007 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/15230 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/337 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/534 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11007 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/15257 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/337 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/534 [00:00<?, ?it/s]
# Attribute loop:   0%|          | 0/11007 [00:00<?, ?it/s]
# neighbor loop:   0%|          | 0/15271 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/337 [00:00<?, ?it/s]
# Predicate loop:   0%|          | 0/534 [00:00<?, ?it/s]

# %%
predicate_prob_dict
# Out:
# {'http://www.w3.org/2004/02/skos/core#prefLabel': {'http://www.w3.org/2004/02/skos/core#prefLabel': 1.0},
#  'http://purl.org/dc/terms/subject': {'http://purl.org/dc/terms/subject': 1.0},
#  'http://dbkwik.webdatacommons.org/ontology/thumbnail': {'http://dbkwik.webdatacommons.org/ontology/thumbnail': 1.0},
#  'http://www.w3.org/2000/01/rdf-schema#comment': {'http://www.w3.org/2000/01/rdf-schema#comment': 1.0},
#  'http://dbkwik.webdatacommons.org/ontology/wikiPageWikiLink': {'http://dbkwik.webdatacommons.org/ontology/wikiPageWikiLink': 1.0},
#  'http://www.w3.org/2004/02/skos/core#broader': {'http://www.w3.org/2004/02/skos/core#broader': 1.0},
#  'http://xmlns.com/foaf/0.1/thumbnail': {'http://xmlns.com/foaf/0.1/thumbnail': 1.0},
#  'http://dbkwik.webdatacommons.org/ontology/abstract': {'http://dbkwik.webdatacommons.org/ontology/abstract': 1.0},
#  'http://xmlns.com/foaf/0.1/depiction': {'http://xmlns.com/foaf/0.1/depiction': 1.0},
#  'http://dbkwik.webdatacommons.org/ontology/wikiPageWikiLinkText': {'http://dbkwik.webdatacommons.org/ontology/wikiPageWikiLinkText': 1.0},
#  'http://dbkwik.webdatacommons.org/ontology/wikiPageDisambiguates': {'http://dbkwik.webdatacommons.org/ontology/wikiPageDisambiguates': 1.0},
#  'http://purl.org/dc/elements/1.1/rights': {'http://purl.org/dc/elements/1.1/rights': 1.0},
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type': {'http://www.w3.org/1999/02/22-rdf-syntax-ns#type': 1.0},
#  'http://www.w3.org/2004/02/skos/core#related': {'http://www.w3.org/2004/02/skos/core#related': 1.0},
#  'http://www.w3.org/2004/02/skos/core#altLabel': {'http://www.w3.org/2004/02/skos/core#altLabel': 1.0},
#  'http://www.w3.org/2000/01/rdf-schema#label': {'http://www.w3.org/2000/01/rdf-schema#label': 1.0},
#  'http://dbkwik.webdatacommons.org/ontology/wikiPageExternalLink': {'http://dbkwik.webdatacommons.org/ontology/wikiPageExternalLink': 1.0},
#  'http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/father': {'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/father': 0.9,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/float': 0.4123417139053345,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/actorsource': 0.2945454545454545,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/weight': 0.42047935724258423,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/weapons': 0.36811256408691406,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/affiliation': 0.42247363924980164,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/mother': 0.48215484619140625,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/season': 0.39353370666503906,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/species': 0.36409759521484375,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/year': 0.360662043094635,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/cp': 0.41346603631973267,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/hair': 0.3691243827342987,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gender': 0.393014132976532,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/base': 0.41588687896728516,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/status': 0.40184450149536133,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/location': 0.4054297208786011,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev': 0.38071179389953613,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/type': 0.4257168769836426,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/occupation': 0.37187129259109497,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/originaldate': 0.36000000000000004,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/color': 0.42000827193260193,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/rank': 0.39766088128089905,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/insignia': 0.3258168399333954,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/name': 0.4405559003353119,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series': 0.39517492055892944,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/caption': 0.3077455461025238,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dp': 0.35057002305984497,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/crew': 0.36421525478363037,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/draft': 0.38088274002075195,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dn': 0.35320091247558594,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image1a': 0.3569409251213074,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/height': 0.4143253564834595,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/eyes': 0.4252774715423584,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/class': 0.41397225856781006,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/co': 0.3785490393638611,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/comm': 0.36303141713142395,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date': 0.405,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/writer': 0.39443567395210266,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/combatant': 0.33383727073669434,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prevep': 0.3204365074634552,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/ya': 0.411225289106369,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/title': 0.3789369463920593,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/capital': 0.38593393564224243,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/ncc': 0.37925148010253906,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/author': 0.4,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/places': 0.3966299891471863,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image': 0.42551109194755554,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arcnext': 0.2786610722541809,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/cf': 0.3855880796909332,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stardate': 0.27155789732933044,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/baseWidth': 0.3418421149253845,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/imagebgcolor': 0.20438513159751892,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/director': 0.4059266149997711,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/siblings': 0.4324095845222473,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/yp': 0.35281437635421753,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/artists': 0.3584213852882385,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/strength': 0.4168062210083008,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next': 0.37938499450683594,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/code': 0.41537562012672424,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/defense': 0.4024803042411804,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/actor': 0.3493328094482422,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gravity': 0.43727391958236694,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stationed': 0.4409005641937256,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/shiploss': 0.31916382908821106,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/epNum': 0.3366158604621887,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/born': 0.41581177711486816,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/system': 0.4158685803413391,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arctitle': 0.332001268863678,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/guest': 0.40527600049972534,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/head': 0.43063998222351074,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/player': 0.39707279205322266,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/quadrant': 0.4129888117313385,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/surface': 0.39380261301994324,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/length': 0.416359007358551,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/nextep': 0.3837735652923584,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/beam': 0.42971178889274597,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/relatives': 0.44463133811950684,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c': 0.38939082622528076,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/girlFriend': 0.3811418414115906,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/speed': 0.41726356744766235,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/floatWidth': 0.31546491384506226,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/casualties': 0.33311977982521057,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/format': 0.3821580708026886,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/seriesb': 0.38402798771858215,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/className': 0.37931978702545166,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stardates': 0.324,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/navy': 0.336365282535553,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/children': 0.37967443466186523,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/language': 0.3822996914386749,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/weapon': 0.41305458545684814,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arcprev': 0.32893192768096924,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planet': 0.43689092993736267,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/formation': 0.41463732719421387,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/shuttle': 0.42258840799331665,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/yard': 0.42844831943511963,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/abrev': 0.33115896582603455,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/plays': 0.39664506912231445,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/description': 0.33821144700050354,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/form': 0.4157697260379791,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/headofstate': 0.36000000000000004,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/place': 0.42241817712783813,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/died': 0.3937397301197052,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/launched': 0.4160577058792114,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/intel': 0.4315643310546875,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/awardedfor': 0.37984782457351685,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/armament': 0.34476855397224426,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prodNum': 0.28378504514694214,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planetName': 0.35741832852363586,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/conc': 0.29679781198501587,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/laid': 0.43585023283958435,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gov': 0.38567054271698,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/result': 0.3707736134529114,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/aff': 0.34607481956481934,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/runtime': 0.3267231285572052,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prodNumber': 0.3428342342376709,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prop': 0.4118660092353821,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/diameter': 0.42310279607772827,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/conflict': 0.4041721820831299,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/religion': 0.34247055649757385,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/agencyName': 0.38027945160865784,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/medium': 0.4226633906364441,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/pages': 0.40189892053604126,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/position': 0.41830968856811523,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/decks': 0.4176326394081116,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/distance': 0.4294959306716919,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/partof': 0.3756829798221588,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/lang': 0.39514169096946716,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/music': 0.3831884264945984,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/artist': 0.380402535200119,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/decomm': 0.2959381937980652,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/spouse': 0.4418157935142517,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/founded': 0.4032876193523407,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/legislature': 0.414806067943573,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/end': 0.3790833055973053,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/bgcolor': 0.25577691197395325,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/hour': 0.39213666319847107,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planets': 0.375177264213562,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/majorSpecies': 0.34347283840179443,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/registry': 0.4095694422721863,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/assignment': 0.4294334650039673,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/atmosphere': 0.4179076552391052,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/motto': 0.4027610421180725,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/altimage': 0.29170382022857666,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/placeOfBirth': 0.3146299719810486,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/money': 0.4229232370853424,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/land': 0.36975347995758057,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/milcom': 0.35146307945251465,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/organizationName': 0.38907891511917114,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/water': 0.43636363636363634,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/vfx': 0.30807381868362427,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/currency': 0.36817553639411926,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/flagship': 0.43787825107574463,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/pressure': 0.41989630460739136,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/publisher': 0.40228623151779175,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/moons': 0.4246502220630646,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/headOfState': 0.36000000000000004,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/anthem': 0.43019944429397583,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/military': 0.38615062832832336,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/released': 0.3916493356227875,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/armaments': 0.31501510739326477,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/executive': 0.39015910029411316,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dur': 0.3598185181617737,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/circumference': 0.27,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/headOfGovernment': 0.32661139965057373,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/width': 0.3956177234649658,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/era': 0.432,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/timeframe': 0.3582102060317993,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/link': 0.38817480206489563,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/found': 0.40673649311065674,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/judiciary': 0.33017587661743164,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/mission': 0.4332875609397888,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/age': 0.40081852674484253,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/built': 0.3796583116054535,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/voiceActor': 0.2945454545454545,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/warpCapable': 0.29595300555229187,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/writers': 0.3666631281375885,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/abbr': 0.32758381962776184,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/variant': 0.3946892023086548,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/size': 0.42977631092071533,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/created': 0.42001986503601074,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/genre': 0.41247937083244324,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/unit': 0.41914746165275574,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/start': 0.38839128613471985,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/vicePresident': 0.22203612327575684,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image2a': 0.3366743326187134,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/producer': 0.3510017693042755,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/craft': 0.4338912069797516,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/death': 0.41888993978500366,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/faction': 0.4353790283203125,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/skin': 0.430482417345047,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/assigned': 0.4199501872062683,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/duration': 0.37554144859313965,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/originalRun': 0.29936861991882324},
#  'http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/gender': {'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gender': 0.9,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/float': 0.3810979425907135,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/actorsource': 0.27502304315567017,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/weight': 0.41085222363471985,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/weapons': 0.38585638999938965,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/affiliation': 0.42330580949783325,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/mother': 0.4039291739463806,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/season': 0.38958749175071716,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/species': 0.3705255091190338,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/father': 0.393014132976532,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/year': 0.383561909198761,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/cp': 0.35661581158638,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/hair': 0.38123756647109985,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/base': 0.4100744128227234,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/status': 0.42386531829833984,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/location': 0.40234413743019104,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev': 0.33058658242225647,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/type': 0.4046517014503479,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/occupation': 0.3837158977985382,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/originaldate': 0.34518250823020935,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/color': 0.4171927273273468,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/rank': 0.41221410036087036,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/insignia': 0.33254823088645935,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/name': 0.4109504818916321,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series': 0.37326985597610474,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/caption': 0.2949832081794739,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dp': 0.34533780813217163,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/crew': 0.3641899526119232,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/draft': 0.3958759903907776,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dn': 0.3315623700618744,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image1a': 0.3499249219894409,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/height': 0.4032107889652252,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/eyes': 0.3824976086616516,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/class': 0.403070867061615,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/co': 0.33717644214630127,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/comm': 0.32171761989593506,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date': 0.40238240361213684,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/writer': 0.3740008473396301,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/combatant': 0.332899272441864,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prevep': 0.2933131754398346,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/ya': 0.37619709968566895,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/title': 0.404104083776474,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/capital': 0.3946129083633423,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/ncc': 0.38490331172943115,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/author': 0.36841559410095215,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/places': 0.4042679965496063,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image': 0.40830373764038086,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arcnext': 0.2566192150115967,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/cf': 0.34151989221572876,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stardate': 0.2978265881538391,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/baseWidth': 0.3416086435317993,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/imagebgcolor': 0.21516312658786774,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/director': 0.3839889168739319,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/siblings': 0.41452938318252563,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/yp': 0.34658753871917725,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/artists': 0.3904491364955902,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/strength': 0.38305899500846863,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next': 0.3490105867385864,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/code': 0.415486216545105,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/defense': 0.38238322734832764,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/actor': 0.3527158200740814,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gravity': 0.40292656421661377,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stationed': 0.3825901746749878,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/shiploss': 0.29461055994033813,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/epNum': 0.30863630771636963,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/born': 0.3827410638332367,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/system': 0.40895789861679077,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arctitle': 0.33175623416900635,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/guest': 0.38196972012519836,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/head': 0.40630435943603516,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/player': 0.3900609016418457,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/quadrant': 0.387669175863266,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/surface': 0.3789142966270447,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/length': 0.39735257625579834,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/nextep': 0.3470502197742462,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/beam': 0.39301174879074097,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/relatives': 0.3977048993110657,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c': 0.35963088274002075,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/girlFriend': 0.36000000000000004,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/speed': 0.4002929925918579,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/floatWidth': 0.3283568024635315,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/casualties': 0.34774231910705566,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/format': 0.39492934942245483,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/seriesb': 0.3674388825893402,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/className': 0.38731324672698975,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stardates': 0.31885209679603577,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/navy': 0.3543071746826172,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/children': 0.3999822735786438,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/language': 0.4064464569091797,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/weapon': 0.40359073877334595,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arcprev': 0.31160402297973633,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planet': 0.3996960520744324,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/formation': 0.37917834520339966,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/shuttle': 0.3787577748298645,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/yard': 0.39540258049964905,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/abrev': 0.31731876730918884,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/plays': 0.39125847816467285,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/description': 0.340237021446228,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/form': 0.38952013850212097,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/headofstate': 0.25084519386291504,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/place': 0.39890536665916443,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/died': 0.3774073123931885,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/launched': 0.37067869305610657,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/intel': 0.3961292505264282,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/awardedfor': 0.36370962858200073,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/armament': 0.37215137481689453,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prodNum': 0.2411140352487564,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planetName': 0.34419921040534973,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/conc': 0.27213603258132935,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/laid': 0.3836670517921448,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gov': 0.3714568018913269,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/result': 0.3764966130256653,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/aff': 0.34822624921798706,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/runtime': 0.3033828139305115,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prodNumber': 0.3346228301525116,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prop': 0.37577497959136963,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/diameter': 0.3906199336051941,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/conflict': 0.41725224256515503,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/religion': 0.3658330738544464,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/agencyName': 0.38745546340942383,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/medium': 0.3833479881286621,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/pages': 0.3797970116138458,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/position': 0.4144804775714874,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/decks': 0.3878965973854065,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/distance': 0.40670937299728394,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/partof': 0.36489588022232056,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/lang': 0.38023650646209717,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/music': 0.38484621047973633,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/artist': 0.3813965320587158,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/decomm': 0.29180216789245605,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/spouse': 0.41647520661354065,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/founded': 0.35332420468330383,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/legislature': 0.4015383720397949,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/end': 0.54,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/bgcolor': 0.2573073208332062,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/hour': 0.369128942489624,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planets': 0.37680089473724365,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/majorSpecies': 0.3490540385246277,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/registry': 0.3819204568862915,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/assignment': 0.4120311439037323,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/atmosphere': 0.4155175983905792,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/motto': 0.35974541306495667,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/altimage': 0.2968495488166809,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/placeOfBirth': 0.3458964228630066,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/money': 0.39396077394485474,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/land': 0.3678465187549591,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/milcom': 0.3435448706150055,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/organizationName': 0.3911595344543457,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/water': 0.39508670568466187,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/vfx': 0.30590707063674927,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/currency': 0.3952498137950897,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/flagship': 0.3977125883102417,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/pressure': 0.3856023848056793,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/publisher': 0.3934277892112732,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/moons': 0.38350921869277954,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/headOfState': 0.35750362277030945,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/anthem': 0.39159536361694336,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/military': 0.4163300693035126,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/released': 0.37269845604896545,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/armaments': 0.35327374935150146,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/executive': 0.3740230202674866,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dur': 0.36000000000000004,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/circumference': 0.324,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/headOfGovernment': 0.3544997572898865,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/width': 0.38481831550598145,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/era': 0.432,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/timeframe': 0.3633546233177185,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/link': 0.39532285928726196,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/found': 0.3625214099884033,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/judiciary': 0.3613418936729431,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/mission': 0.40903395414352417,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/age': 0.432,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/built': 0.36938250064849854,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/voiceActor': 0.28214335441589355,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/warpCapable': 0.30327877402305603,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/writers': 0.38956087827682495,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/abbr': 0.2970529794692993,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/variant': 0.3872582018375397,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/size': 0.39793163537979126,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/created': 0.3845808506011963,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/genre': 0.43636363636363634,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/unit': 0.38611161708831787,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/start': 0.35641783475875854,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/vicePresident': 0.27,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image2a': 0.3384345769882202,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/producer': 0.3418038487434387,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/craft': 0.3921137750148773,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/death': 0.39578062295913696,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/faction': 0.3960023820400238,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/skin': 0.39622762799263,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/assigned': 0.4092079699039459,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/duration': 0.3803335428237915,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/originalRun': 0.2914797067642212},
#  'http://dbkwik.webdatacommons.org/memory-alpha.wikia.com/property/image': {'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image': 0.9,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/float': 0.42597442865371704,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/actorsource': 0.2943713068962097,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/weight': 0.4346546530723572,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/weapons': 0.37129348516464233,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/affiliation': 0.421867698431015,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/mother': 0.4288024306297302,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/season': 0.3897293210029602,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/species': 0.37106114625930786,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/father': 0.42551109194755554,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/year': 0.36171334981918335,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/cp': 0.4011004567146301,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/hair': 0.37904560565948486,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gender': 0.40830373764038086,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/base': 0.4281166195869446,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/status': 0.4158264100551605,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/location': 0.42593318223953247,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prev': 0.3691255450248718,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/type': 0.4325471818447113,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/occupation': 0.37638068199157715,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/originaldate': 0.37250059843063354,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/color': 0.4527759552001953,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/rank': 0.41167518496513367,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/insignia': 0.33121365308761597,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/name': 0.4354953169822693,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/series': 0.3968271017074585,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/caption': 0.33367353677749634,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dp': 0.35361695289611816,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/crew': 0.3813263177871704,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/draft': 0.3913930058479309,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dn': 0.34369102120399475,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image1a': 0.57,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/height': 0.4164716899394989,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/eyes': 0.4262450635433197,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/class': 0.41004008054733276,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/co': 0.37707239389419556,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/comm': 0.37686216831207275,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date': 0.40550363063812256,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/writer': 0.4025692045688629,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/combatant': 0.3378872871398926,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prevep': 0.33723974227905273,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/ya': 0.40725988149642944,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/title': 0.38917076587677,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/capital': 0.40342777967453003,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/ncc': 0.39152371883392334,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/author': 0.38178277015686035,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/places': 0.4075539708137512,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arcnext': 0.28003543615341187,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/cf': 0.380121111869812,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stardate': 0.29658377170562744,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/baseWidth': 0.3518672287464142,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/imagebgcolor': 0.54,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/director': 0.41447365283966064,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/siblings': 0.4182145893573761,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/yp': 0.35400962829589844,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/artists': 0.3899531662464142,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/strength': 0.40490615367889404,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next': 0.36796391010284424,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/code': 0.43537259101867676,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/defense': 0.3972730338573456,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/actor': 0.35881301760673523,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gravity': 0.43231201171875,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stationed': 0.40981078147888184,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/shiploss': 0.31697624921798706,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/epNum': 0.33699560165405273,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/born': 0.401808500289917,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/system': 0.4386107325553894,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arctitle': 0.3522524833679199,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/guest': 0.3986343443393707,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/head': 0.44111374020576477,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/player': 0.3978053033351898,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/quadrant': 0.417464941740036,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/surface': 0.4131367802619934,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/length': 0.4268723428249359,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/nextep': 0.37817248702049255,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/beam': 0.42889654636383057,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/relatives': 0.4306879937648773,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c': 0.37963783740997314,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/girlFriend': 0.3699314594268799,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/speed': 0.4288526773452759,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/floatWidth': 0.3460284471511841,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/casualties': 0.34267181158065796,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/format': 0.41379669308662415,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/seriesb': 0.3789229393005371,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/className': 0.38400334119796753,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stardates': 0.3149418532848358,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/navy': 0.3574103116989136,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/children': 0.38457798957824707,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/language': 0.405,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/weapon': 0.40933990478515625,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arcprev': 0.3567231297492981,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planet': 0.4398612678050995,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/formation': 0.41122326254844666,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/shuttle': 0.42433440685272217,
# ...
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/crew': 0.3737122416496277,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/draft': 0.34437477588653564,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dn': 0.2866884469985962,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image1a': 0.3374830484390259,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/height': 0.3541599214076996,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/eyes': 0.3624722957611084,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/class': 0.34915611147880554,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/co': 0.33111774921417236,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/comm': 0.33690395951271057,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/date': 0.3664191961288452,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/writer': 0.3817689120769501,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/combatant': 0.30655381083488464,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prevep': 0.2819356918334961,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/ya': 0.34389081597328186,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/title': 0.34611302614212036,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/capital': 0.35721147060394287,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/ncc': 0.33545881509780884,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/author': 0.3893730640411377,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/places': 0.3485391438007355,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image': 0.376423716545105,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arcnext': 0.26379090547561646,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/cf': 0.33047690987586975,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stardate': 0.3049220144748688,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/baseWidth': 0.3156169354915619,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/imagebgcolor': 0.2142694890499115,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/director': 0.37006717920303345,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/siblings': 0.369794100522995,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/yp': 0.2957649230957031,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/artists': 0.34948304295539856,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/strength': 0.35960960388183594,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/next': 0.3159381151199341,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/code': 0.3552992641925812,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/defense': 0.35776397585868835,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/actor': 0.3534276485443115,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gravity': 0.36374157667160034,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stationed': 0.3403453826904297,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/shiploss': 0.29218000173568726,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/epNum': 0.3009902238845825,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/born': 0.3435232639312744,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/system': 0.3755524754524231,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arctitle': 0.2982783317565918,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/guest': 0.37297046184539795,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/head': 0.3750692307949066,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/player': 0.3492254316806793,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/quadrant': 0.34401848912239075,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/surface': 0.3809797763824463,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/length': 0.3557698130607605,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/nextep': 0.29864007234573364,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/beam': 0.35266080498695374,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/relatives': 0.36517947912216187,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/c': 0.32240331172943115,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/girlFriend': 0.35147255659103394,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/speed': 0.35668259859085083,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/floatWidth': 0.29487016797065735,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/casualties': 0.33937689661979675,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/format': 0.3712351620197296,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/seriesb': 0.3390243649482727,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/className': 0.36160463094711304,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/stardates': 0.29999637603759766,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/navy': 0.3488042950630188,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/children': 0.37159162759780884,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/language': 0.3715945780277252,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/weapon': 0.3641831576824188,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/arcprev': 0.29747408628463745,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planet': 0.38506001234054565,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/formation': 0.37004977464675903,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/shuttle': 0.37329381704330444,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/yard': 0.36871838569641113,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/abrev': 0.3039981722831726,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/plays': 0.33777040243148804,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/description': 0.35766077041625977,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/form': 0.33733952045440674,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/headofstate': 0.27,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/place': 0.36143845319747925,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/died': 0.36576926708221436,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/launched': 0.3718687891960144,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/intel': 0.3601960241794586,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/awardedfor': 0.33881792426109314,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/armament': 0.3523816466331482,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prodNum': 0.22935551404953003,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planetName': 0.3548397719860077,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/conc': 0.30265283584594727,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/laid': 0.349102646112442,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/gov': 0.3793226480484009,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/result': 0.35100245475769043,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/aff': 0.31116288900375366,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/runtime': 0.3221983015537262,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prodNumber': 0.32013586163520813,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/prop': 0.3082629442214966,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/diameter': 0.3558502793312073,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/conflict': 0.3705926537513733,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/religion': 0.3514944314956665,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/agencyName': 0.3731820583343506,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/medium': 0.33560460805892944,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/pages': 0.3733624219894409,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/position': 0.35345298051834106,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/decks': 0.34821370244026184,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/distance': 0.3679218292236328,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/partof': 0.3412095904350281,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/lang': 0.3772554397583008,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/music': 0.3777576982975006,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/artist': 0.35646557807922363,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/decomm': 0.292676717042923,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/spouse': 0.3688238263130188,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/founded': 0.3694288730621338,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/legislature': 0.357110857963562,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/end': 0.3459939658641815,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/bgcolor': 0.25354480743408203,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/hour': 0.33189165592193604,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/planets': 0.3497103452682495,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/majorSpecies': 0.3258401155471802,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/registry': 0.3971741795539856,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/assignment': 0.3601069450378418,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/atmosphere': 0.3575092554092407,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/motto': 0.35676878690719604,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/altimage': 0.3048154413700104,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/placeOfBirth': 0.3114508390426636,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/money': 0.3611767888069153,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/land': 0.350849986076355,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/milcom': 0.3215828537940979,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/organizationName': 0.374148428440094,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/water': 0.36051252484321594,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/vfx': 0.2697986960411072,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/currency': 0.36196058988571167,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/flagship': 0.3811066150665283,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/pressure': 0.3425070643424988,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/publisher': 0.3891637623310089,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/moons': 0.3419427275657654,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/headOfState': 0.30763620138168335,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/anthem': 0.36305364966392517,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/military': 0.3678990602493286,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/released': 0.36371761560440063,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/armaments': 0.3291478455066681,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/executive': 0.36765748262405396,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/dur': 0.31152573227882385,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/circumference': 0.22633573412895203,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/headOfGovernment': 0.3396630585193634,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/width': 0.3401326835155487,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/era': 0.3358278274536133,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/timeframe': 0.3290823698043823,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/link': 0.39989548921585083,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/found': 0.3564305901527405,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/judiciary': 0.3338601589202881,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/mission': 0.38037538528442383,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/age': 0.3648644685745239,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/built': 0.35090118646621704,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/voiceActor': 0.29901885986328125,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/warpCapable': 0.29218924045562744,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/writers': 0.35205385088920593,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/abbr': 0.29749560356140137,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/variant': 0.3699932098388672,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/size': 0.405,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/created': 0.36947116255760193,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/genre': 0.3660218417644501,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/unit': 0.3506937026977539,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/start': 0.3434754014015198,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/vicePresident': 0.30857142857142855,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/image2a': 0.3271045684814453,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/producer': 0.34371697902679443,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/craft': 0.357256144285202,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/death': 0.3629952371120453,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/faction': 0.3501438498497009,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/skin': 0.35857030749320984,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/assigned': 0.3534575402736664,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/duration': 0.3581743538379669,
#   'http://dbkwik.webdatacommons.org/stexpanded.wikia.com/property/originalRun': 0.3188348114490509}}
